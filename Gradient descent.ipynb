# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(-6,4,100)
y = x**2+2*x+5
plt.plot(x,y)

# %%
x = 3
alpha = 0.8
iterationNum = 100

# %%
for i in range(iterationNum):
    x = x - alpha*(2*x+2)

# %%
print(x)
# Out:
# -1.0
